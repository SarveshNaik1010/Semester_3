# %%
import pandas as pd

# Fetching data
bengaluruHouseData = pd.read_csv("./Bengaluru_House_Data.csv");
bengaluruHouseData
# Out:
#                  area_type   availability                  location  \
# 0     Super built-up  Area         19-Dec  Electronic City Phase II
# 1               Plot  Area  Ready To Move          Chikka Tirupathi
# 2           Built-up  Area  Ready To Move               Uttarahalli
# 3     Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4     Super built-up  Area  Ready To Move                  Kothanur
# ...                    ...            ...                       ...
# 1389        Built-up  Area  Ready To Move         Bannerghatta Road
# 1390  Super built-up  Area  Ready To Move            Sarjapur  Road
# 1391        Built-up  Area  Ready To Move                  Sarjapur
# 1392  Super built-up  Area  Ready To Move              Billekahalli
# 1393            Plot  Area  Ready To Move         Bagalur Main Road
#
#            size  society total_sqft  bath  balcony   price
# 0         2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %% [markdown]
# ### A. Data for formats of ```merging```, ```grouping``` and ```concatenation```

# %%
# 1. Data Wrangling

# Missing field count
nullFieldsCount = bengaluruHouseData.isnull().sum()
print(nullFieldsCount)
# Out:
# area_type         0
# availability      0
# location          1
# size              1
# society         544
# total_sqft        0
# bath             11
# balcony          71
# price             0
# dtype: int64

# %%
newBengaluruHouseData = bengaluruHouseData.fillna({'society': 'ArsiaEx', 'bath': '2.0', 'size': "2BHK" })
newBengaluruHouseData
# Out:
#                  area_type   availability                  location  \
# 0     Super built-up  Area         19-Dec  Electronic City Phase II
# 1               Plot  Area  Ready To Move          Chikka Tirupathi
# 2           Built-up  Area  Ready To Move               Uttarahalli
# 3     Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4     Super built-up  Area  Ready To Move                  Kothanur
# ...                    ...            ...                       ...
# 1389        Built-up  Area  Ready To Move         Bannerghatta Road
# 1390  Super built-up  Area  Ready To Move            Sarjapur  Road
# 1391        Built-up  Area  Ready To Move                  Sarjapur
# 1392  Super built-up  Area  Ready To Move              Billekahalli
# 1393            Plot  Area  Ready To Move         Bagalur Main Road
#
#            size  society total_sqft bath  balcony   price
# 0         2 BHK  Coomee        1056  2.0      1.0   39.07
# ...

# %% [markdown]
# # Merging

# %%
# Creating subset with different columns
tableHalf1 = newBengaluruHouseData[['area_type','availability','location','size']]
tableHalf2 = newBengaluruHouseData[['area_type','society','total_sqft','bath', 'balcony', 'price']]

tableHalf1.merge(tableHalf2)
# Out:
#                    area_type   availability                  location  \
# 0       Super built-up  Area         19-Dec  Electronic City Phase II
# 1       Super built-up  Area         19-Dec  Electronic City Phase II
# 2       Super built-up  Area         19-Dec  Electronic City Phase II
# 3       Super built-up  Area         19-Dec  Electronic City Phase II
# 4       Super built-up  Area         19-Dec  Electronic City Phase II
# ...                      ...            ...                       ...
# 957973            Plot  Area  Ready To Move         Bagalur Main Road
# 957974            Plot  Area  Ready To Move         Bagalur Main Road
# 957975            Plot  Area  Ready To Move         Bagalur Main Road
# 957976            Plot  Area  Ready To Move         Bagalur Main Road
# 957977            Plot  Area  Ready To Move         Bagalur Main Road
#
#              size  society total_sqft bath  balcony   price
# 0           2 BHK  Coomee        1056  2.0      1.0   39.07
# ...

# %%
tableHalf1.merge(tableHalf2,how='outer')
# Out:
#                    area_type   availability      location   size  society  \
# 0             Built-up  Area  Ready To Move   Uttarahalli  3 BHK  ArsiaEx
# 1             Built-up  Area  Ready To Move   Uttarahalli  3 BHK  ArsiaEx
# 2             Built-up  Area  Ready To Move   Uttarahalli  3 BHK  ArsiaEx
# 3             Built-up  Area  Ready To Move   Uttarahalli  3 BHK  ArsiaEx
# 4             Built-up  Area  Ready To Move   Uttarahalli  3 BHK  Kantsce
# ...                      ...            ...           ...    ...      ...
# 957973  Super built-up  Area  Ready To Move  Billekahalli  2 BHK  Kaestid
# 957974  Super built-up  Area  Ready To Move  Billekahalli  2 BHK  GonumPl
# 957975  Super built-up  Area  Ready To Move  Billekahalli  2 BHK  Krine O
# 957976  Super built-up  Area  Ready To Move  Billekahalli  2 BHK  SocusHi
# 957977  Super built-up  Area  Ready To Move  Billekahalli  2 BHK  Dintsmi
#
#        total_sqft bath  balcony  price
# 0            1440  2.0      3.0   62.0
# ...

# %%
tableHalf1.merge(tableHalf2,how='right')
# Out:
#                    area_type   availability                  location  \
# 0       Super built-up  Area         19-Dec  Electronic City Phase II
# 1       Super built-up  Area  Ready To Move        Lingadheeranahalli
# 2       Super built-up  Area  Ready To Move                  Kothanur
# 3       Super built-up  Area  Ready To Move                Whitefield
# 4       Super built-up  Area         18-May          Old Airport Road
# ...                      ...            ...                       ...
# 957973            Plot  Area  Ready To Move      Devasandra Extension
# 957974            Plot  Area  Ready To Move              Marathahalli
# 957975            Plot  Area         18-Feb     1st Block HRBR Layout
# 957976            Plot  Area  Ready To Move    Kengeri Satellite Town
# 957977            Plot  Area  Ready To Move         Bagalur Main Road
#
#              size  society total_sqft bath  balcony   price
# 0           2 BHK  Coomee        1056  2.0      1.0   39.07
# ...

# %%
tableHalf1.merge(tableHalf2,how='left')
# Out:
#                    area_type   availability                  location  \
# 0       Super built-up  Area         19-Dec  Electronic City Phase II
# 1       Super built-up  Area         19-Dec  Electronic City Phase II
# 2       Super built-up  Area         19-Dec  Electronic City Phase II
# 3       Super built-up  Area         19-Dec  Electronic City Phase II
# 4       Super built-up  Area         19-Dec  Electronic City Phase II
# ...                      ...            ...                       ...
# 957973            Plot  Area  Ready To Move         Bagalur Main Road
# 957974            Plot  Area  Ready To Move         Bagalur Main Road
# 957975            Plot  Area  Ready To Move         Bagalur Main Road
# 957976            Plot  Area  Ready To Move         Bagalur Main Road
# 957977            Plot  Area  Ready To Move         Bagalur Main Road
#
#              size  society total_sqft bath  balcony   price
# 0           2 BHK  Coomee        1056  2.0      1.0   39.07
# ...

# %% [markdown]
# # Grouping

# %%
print("Total price of all houses with area_type categoery wise area_type")
pd.DataFrame(newBengaluruHouseData.groupby("area_type")['price'].sum())
# Out:
# Total price of all houses with area_type categoery wise area_type
#                           price
# area_type
# Built-up  Area        25138.830
# Carpet  Area            731.300
# Plot  Area            39974.645
# Super built-up  Area  86818.440

# %%
newHouses = pd.DataFrame([{
    "area_type": "Plot Area",
    "availability": "Ready To Move",
    "location": "Bagalur Main Road",
    "size": "4 Bedroom",
    "society": 'Vantage', 
    "total_sqft": 3600,
    "bath": 4,
    "balcony": 1.0, 
    "price": 300
}, {
    "area_type": "Plot Area",
    "availability": "Ready To Move",
    "location": "Bagalur Main Road",
    "size": "2 Bedroom",
    "society": 'Vantage', 
    "total_sqft": 3600,
    "bath": 3,
    "balcony": 1.0, 
    "price": 200
}])

pd.concat([newBengaluruHouseData, newHouses], axis=0)
# Out:
#                  area_type   availability                  location  \
# 0     Super built-up  Area         19-Dec  Electronic City Phase II
# 1               Plot  Area  Ready To Move          Chikka Tirupathi
# 2           Built-up  Area  Ready To Move               Uttarahalli
# 3     Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4     Super built-up  Area  Ready To Move                  Kothanur
# ...                    ...            ...                       ...
# 1391        Built-up  Area  Ready To Move                  Sarjapur
# 1392  Super built-up  Area  Ready To Move              Billekahalli
# 1393            Plot  Area  Ready To Move         Bagalur Main Road
# 0                Plot Area  Ready To Move         Bagalur Main Road
# 1                Plot Area  Ready To Move         Bagalur Main Road
#
#            size  society total_sqft bath  balcony   price
# 0         2 BHK  Coomee        1056  2.0      1.0   39.07
# ...
