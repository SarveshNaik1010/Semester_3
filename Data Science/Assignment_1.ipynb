# %%
import pandas as pd

# rawData = [["Sarvesh", 207, "1"], ["Anurag", 207, "2"], ["Praneel", 304, "3"], ["Vedant", 305, "3"]]
# structuredData = pd.DataFrame(rawData, columns=["Name", "BedNo", "Floor"])

structuredData = pd.read_csv("Packaged Food Items.csv");

structuredData
# Out:
#                  Food Brand          Company  Weight  Price  Sugar  \
# 0                      Oreo         Mondelez     120     30   14.0
# 1                     Maggi           Nestle      70     12    2.0
# 2                      Lays          PepsiCo      52     20    1.2
# 3                Dairy Milk          Cadbury      36     40   20.0
# 4                   Parle-G   Parle Products      70      5   12.0
# 5                    KitKat           Nestle      37     30   21.3
# 6                    Bingo!              ITC      45     10    0.9
# 7                 Tropicana          PepsiCo     200     50   20.0
# 8                Marie Gold        Britannia      70     15   12.0
# 9                    5 Star          Cadbury      45     20   24.0
# 10                  Nutella          Ferrero     290    350   56.0
# 11                    Pepsi          PepsiCo     330     40   33.0
# 12                   Sprite        Coca-Cola     330     40   36.0
# ...

# %%
structuredData.fillna("❓")
# Out:
#                  Food Brand          Company  Weight  Price  Sugar  \
# 0                      Oreo         Mondelez     120     30   14.0
# 1                     Maggi           Nestle      70     12    2.0
# 2                      Lays          PepsiCo      52     20    1.2
# 3                Dairy Milk          Cadbury      36     40   20.0
# 4                   Parle-G   Parle Products      70      5   12.0
# 5                    KitKat           Nestle      37     30   21.3
# 6                    Bingo!              ITC      45     10    0.9
# 7                 Tropicana          PepsiCo     200     50   20.0
# 8                Marie Gold        Britannia      70     15   12.0
# 9                    5 Star          Cadbury      45     20   24.0
# 10                  Nutella          Ferrero     290    350   56.0
# 11                    Pepsi          PepsiCo     330     40   33.0
# 12                   Sprite        Coca-Cola     330     40   36.0
# ...

# %%
structuredData["Company"].mode()
# Out:
# 0    Cadbury
# 1    PepsiCo
# Name: Company, dtype: object

# %%
print(structuredData["Protein"].max())
# Out:
# 13.0

# %%
print(structuredData["Fat"].median())
# Out:
# 11.5

# %%
print(structuredData["Sugar"].mean())
# Out:
# 18.095

# %%
print(structuredData.values)
# Out:
# [['Oreo' 'Mondelez' 120 30 14.0 68.3 5.0 22.5 10.0 0.1 0 400 3.6 14.0
#   14.0 0 0 2 15.0 30 160 45 'Wheat Flour, Sugar, Palm Oil, Cocoa, etc.'
#   'Wheat, Soy' 9 'India']
#  ['Maggi' 'Nestle' 70 12 2.0 44.0 7.0 11.0 5.0 0.1 5 760 2.0 2.0 2.0 0 0
#   2 8.0 70 310 70 'Wheat Flour, Palm Oil, Salt, etc.' 'Wheat, Soy' 9
#   'India']
#  ['Lays' 'PepsiCo' 52 20 1.2 15.7 2.0 10.5 3.0 0.2 0 180 1.2 1.2 1.2 0 0
#   0 2.0 28 160 60 'Potatoes, Vegetable Oil, Salt, etc.' 'Potatoes, Soy' 6
#   'India']
#  ['Dairy Milk' 'Cadbury' 36 40 20.0 29.0 3.4 12.0 7.0 0.1 5 22 0.2 20.0
#   15.0 0 0 8 2.0 36 200 100 'Milk, Sugar, Cocoa, Butter, etc.'
#   'Milk, Soy' 12 'India']
#  ['Parle-G' 'Parle Products' 70 5 12.0 60.0 6.0 20.0 10.0 0.1 0 450 2.0
#   12.0 10.0 0 0 4 10.0 35 180 70 'Wheat Flour, Sugar, Palm Oil, etc.'
#   'Wheat, Milk, Soy' 9 'India']
#  ['KitKat' 'Nestle' 37 30 21.3 50.3 7.6 18.9 11.0 0.2 10 22 1.3 21.3 15.3
#   2 0 12 2.6 37 218 100 'Milk Chocolate, Sugar, Wheat Flour, etc.'
# ...
